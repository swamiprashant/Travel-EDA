# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Travel.csv')
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.isnull().sum().sort_values(ascending =False)
# Out:
# DurationOfPitch             251
# MonthlyIncome               233
# Age                         226
# NumberOfTrips               140
# NumberOfChildrenVisiting     66
# NumberOfFollowups            45
# PreferredPropertyStar        26
# TypeofContact                25
# Designation                   0
# OwnCar                        0
# PitchSatisfactionScore        0
# Passport                      0
# CustomerID                    0
# MaritalStatus                 0
# ProdTaken                     0
# NumberOfPersonVisiting        0
# Gender                        0
# Occupation                    0
# CityTier                      0
# ProductPitched                0
# dtype: int64

# %%
df.dropna(axis=0, inplace = True)

# %%
df.isnull().sum().sort_values(ascending =False)
# Out:
# CustomerID                  0
# ProdTaken                   0
# Designation                 0
# NumberOfChildrenVisiting    0
# OwnCar                      0
# PitchSatisfactionScore      0
# Passport                    0
# NumberOfTrips               0
# MaritalStatus               0
# PreferredPropertyStar       0
# ProductPitched              0
# NumberOfFollowups           0
# NumberOfPersonVisiting      0
# Gender                      0
# Occupation                  0
# DurationOfPitch             0
# CityTier                    0
# TypeofContact               0
# Age                         0
# MonthlyIncome               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4128 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4128 non-null   int64
#  1   ProdTaken                 4128 non-null   int64
#  2   Age                       4128 non-null   float64
#  3   TypeofContact             4128 non-null   object
#  4   CityTier                  4128 non-null   int64
#  5   DurationOfPitch           4128 non-null   float64
#  6   Occupation                4128 non-null   object
#  7   Gender                    4128 non-null   object
#  8   NumberOfPersonVisiting    4128 non-null   int64
#  9   NumberOfFollowups         4128 non-null   float64
#  10  ProductPitched            4128 non-null   object
#  11  PreferredPropertyStar     4128 non-null   float64
#  12  MaritalStatus             4128 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
cats = []
nums = []
for i in df.columns:
    
    if df[i].dtypes == 'object':
        cats.append(i)
    else:
        nums.append(i)

# %%
cats
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
nums
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Fe Male'], dtype=object)

# %%
df.replace("Fe Male", "Female", inplace=True)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 5      200005          0  32.0  Company Invited         1              8.0
#
#     Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0     Salaried  Female                       3                3.0
# 1     Salaried    Male                       3                4.0
# 2  Free Lancer    Male                       3                4.0
# 3     Salaried  Female                       2                3.0
# 5     Salaried    Male                       3                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
for cat_column in cats:
    plt.figure(figsize=(8, 6))
    sns.countplot(x= cat_column, data = df, palette = 'viridis')
    plt.title(f'Univariate analysis- {cat_column}')
    plt.show()

# %%
# Insight: Salaried and small business people travale more than Large business and freelance. both male and female are mostly like to travel deluxe and basic coach. married are mostly travel.

# %%
nums
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
for num_column in nums:
    plt.figure(figsize = (8, 6))
    sns.histplot(df[num_column], kde = True, color = 'skyblue')
    plt.title(f'univariate analysis - {num_column}')
    plt.show()

# %%
# Insight : monthly income of mejority of travelers are between 20k-40k.
#Age of mostly travelers are between 30-50 years.
#number of folloups are between 3-5.
#Number of trips per month is between 1-8.

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
cats
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
df['TypeofContact'].unique()
# Out:
# array(['Self Enquiry', 'Company Invited'], dtype=object)

# %%
plt.figure(figsize = (10, 6))
sns.histplot(x = 'TypeofContact', data = df, color = 'pink', palette = "viridis")
plt.title("Self Enquiry vs Company Invited")
plt.show()

# %%
# mejority people they use to self Enquiry for travel.

# %%
sns.histplot(df["Passport"], color = 'red', palette = "viridis")
# Out:
# <AxesSubplot: xlabel='Passport', ylabel='Count'>

# %%
# more than half of people have passport.

# %%
nums
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
df['OwnCar'].unique()
# Out:
# array([1, 0])

# %%
df.describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4128.000000  4128.000000  4128.000000  4128.000000      4128.000000
# mean   202527.763808     0.193072    37.231831     1.663275        15.584787
# std      1409.439133     0.394757     9.174521     0.920640         8.398142
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201320.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202603.500000     0.000000    36.000000     1.000000        14.000000
# 75%    203748.250000     0.000000    43.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4128.000000        4128.000000            4128.000000
# mean                 2.949370           3.741521               3.578488
# ...

# %%
df[nums].describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4128.000000  4128.000000  4128.000000  4128.000000      4128.000000
# mean   202527.763808     0.193072    37.231831     1.663275        15.584787
# std      1409.439133     0.394757     9.174521     0.920640         8.398142
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201320.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202603.500000     0.000000    36.000000     1.000000        14.000000
# 75%    203748.250000     0.000000    43.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4128.000000        4128.000000            4128.000000
# mean                 2.949370           3.741521               3.578488
# ...

# %%
df[cats].describe()
# Out:
#        TypeofContact Occupation Gender ProductPitched MaritalStatus  \
# count           4128       4128   4128           4128          4128
# unique             2          4      2              5             4
# top     Self Enquiry   Salaried   Male          Basic       Married
# freq            2918       1999   2463           1615          1990
#
#        Designation
# count         4128
# unique           5
# top      Executive
# freq          1615

# %%
# Bi-variate analysis

# %%
sns.scatterplot(x = 'Age', y = 'DurationOfPitch', palette = 'coolwarm', hue = 'ProdTaken', data = df)
plt.show()

# %%
sns.barplot(x = 'ProductPitched', y = 'PitchSatisfactionScore', data = df,
